# %% [markdown]
# 1. What are the key tasks that machine learning entails? What does data pre-processing imply?
#     1. DAta Collection
#     2. DAta Validation
#     3. DAta Cleaning
#     4. Data Analysis- EXploratory Data Analysis
#     5. DAta Preprocessing
#     6. Feature engineering
#     7. Model Training
#     8. HyperTuning
#     9. Productionizing
#     10. Model Retraining
# Data Preprocessing involves transformation Techniques, Categorical Variable encoding Techniques like one hot encoding Mean Encoding,Label Encoding, Target Guided Encoding, handling Missing Value Techniques, Handling Diuplicate VAlues, Handling Outliers, Normalising the data set using techniques like Box-Cox Transformation, Log Transformation, Power Transformation,etc. Many of the Dtaa preprocessing techniques over laps with Feature Engiineering techniques.
#
# 2. Describe quantitative and qualitative data in depth. Make a distinction between the two.
#
# 1.Quantitative:
#     1.1 Discrete EXample: Number of Passengers onboarding into a flight.
#     1.2 COntinous eXAMPLE: Height, Age,etc
#         1.2.1 Ratio:
# 1. Absolute Point Zero – Ratio data is measured on a ratio scale. One of the distinctive characteristics of ratio data is the true absolute zero point, which makes the data relevant and meaningful in a manner where it is right to say, “one object is twice as long as the other” or 4 has twice the value as 2.
#
# 2. No Negative Numerical Value – Ratio data doesn’t have any negative numerical value. For a value to be a ratio data researcher, first must evaluate if it meets all the criteria of interval data and has an absolute zero point. For example, weight cannot be negative, -20 Kgs doesn’t exist.
#
# 3. Calculation – Ratio data values can be added, subtracted, divided, and multiplied. A unique statistical analysis is possible for ratio data. Chi-square can be calculated using a ratio scale for ratio data. Mean, mode and median can also be calculated for the ratio data.
#
#         1.2.2 Interval: Interval data, also called an integer, is defined as a data type which is measured along a scale, in which each point is placed at equal distance from one another. Interval data always appears in the form of numbers or numerical values where the distance between the two points is standardized and equal.
#
# Interval data cannot be multiplied or divided, however, it can be added or subtracted. Interval data is measured on an interval scale. A simple example of interval data: The difference between 100 degrees Fahrenheit and 90 degrees Fahrenheit is the same as 60 degrees Fahrenheit and 70 degrees Fahrenheit.
# Interval data doesn’t have a defined absolute zero point which is present in ratio data. The lack of absolute point zero makes comparisons of direct magnitudes impossible. For example, Object A is twice as large as Object B is not a possibility in interval data.  Absolute zero point is arbitrary, which means a variable can be measured even if it has a negative value like temperature can be -10 below zero but height cannot be below zero.
# Example:
# 1. One can measure time during the day using a 12-hour clock, this is a good example of interval data. Time in a 12-hour format is a rotational measure that keeps restarting from zero at set periodicity. These numbers are on an interval scale as the distance between them is measurable and comparable. For example, the difference between 5 minutes and 10 minutes is the same as 15 minutes and 20 minutes in a 12-hour clock.
#
# 2. The temperature measured in Fahrenheit and Celsius but not in Kelvin. If you measure temperature in Fahrenheit and Celsius then it will be considered interval data as 0 is arbitrary. But in Kelvin, 0 is absolute. There can’t be a temperature below zero degrees in Kelvin.
#
# 3. When you calculate intelligence score in an IQ test. There is no zero point for IQ. According to psychological studies, a person cannot have zero intelligence, therefore in this example, zero is arbitrary. IQ is numeric data expressed in intervals using a fixed measurement scale.
#
# 4. Test scores of examination like SAT. Scores in SAT test are in the range of 200-800. The numbers from 0 to 200 are not used when they scale the raw score (number of questions answered correctly) to the section score. The reference point is not an absolute zero, thus, it qualifies to become interval data.
#
#
# 2.Qualitative
#     2.1 Ordinal: Where order matters. EXample: Movie Ratings["Good","BAd","Worst"]
#     2.2 Nominal: Notational DAta where order doesnt matter. EXample Gender["MAle","Female"]
#
#
#
# 3. Create a basic data collection that includes some sample records. Have at least one attribute from each of the machine learning data types.

# %%
import pandas as pd
d = {"Nominal_EMPID":[ 11221,11222],
    "Nominal_Gender": ["Male","Female"],
     "Ordinal_PositionLevel" : ["l1", "l2"],
     "Interval_Age":[35,41],
     "Ratio_Salary": [1000000,1200000] 
    }
pd.DataFrame(d)
# Out:
#    Nominal_EMPID Nominal_Gender Ordinal_PositionLevel  Interval_Age  \
# 0          11221           Male                    l1            35
# 1          11222         Female                    l2            41
#
#    Ratio_Salary
# 0       1000000
# 1       1200000

# %% [markdown]
# 4. What are the various causes of machine learning data issues? What are the ramifications?
#     1. It needs good amount of data to train the model
#     2. Overfitting: When the parameters of the model are tweaked to an extent that it yields very less error with training data but produces high error to any unseen data like train-dev, validation or test data resulting in high variance.
#     3. Underfitting: When the model is not trained enough/properly to even find the hidden pattern of the training data then it results in high bias and thus leading to high train error. The model is not able to capture the variance of the training data even.
#     4. Bias Variance Trade off: When the model is simple it produces high bias , when the model is complex it produces high variance both result in one or other type of error. Reducing one type of error increase the chance of introoducing other type of error. There is always an optimum point in between where it produces low variance and low squared bias which can be achieved via different regulaization techniques.
#     5. Data mismatch: Train Data, Validation Data and Test Data are not representative of one another.
#     6. pOOR QUALITY DATA
#     7. Irrelevent Features
#
#
# 5. Demonstrate various approaches to categorical data exploration with appropriate examples.

# %% [markdown]
# ![image10.jpeg](attachment:image10.jpeg)

# %% [markdown]
# ![image8.jpeg](attachment:image8.jpeg)

# %% [markdown]
# ![image6.jpeg](attachment:image6.jpeg)

# %% [markdown]
# ![image5.jpeg](attachment:image5.jpeg)

# %% [markdown]
# ![image4.jpeg](attachment:image4.jpeg)

# %% [markdown]
# ![image2.jpeg](attachment:image2.jpeg)

# %% [markdown]
# ![image1.jpeg](attachment:image1.jpeg)

# %% [markdown]
# ![image0.jpeg](attachment:image0.jpeg)

# %%
6. How would the learning activity be affected if certain variables have missing values? Having said that, what can be done about it?

7. Describe the various methods for dealing with missing data values in depth.

# %% [markdown]
# ![image13.jpeg](attachment:image13.jpeg)

# %% [markdown]
# ![image11.jpeg](attachment:image11.jpeg)

# %% [markdown]
# 8. What are the various data pre-processing techniques? Explain dimensionality reduction and function selection in a few words.
# 1.DAta Cleaning
# Handling Missing Values
# Handling Noisy Data
# 2.DAta Transformation
# Normalisation
# Attribute Selection
# Discretization
# 3. Data Reduction
# Attribute Subset Selection
# Dimensionality Reduction: Capturing the variance of the dataset either by manifold learning or projecting the training set down to d dimension

# %% [markdown]
# 9.Answer
#
# i. What is the IQR? What criteria are used to assess it?
# IQR stands for Interquartile range which is the difference between q1 and q3. It is also used to calculate outliers.
#     1. Min Value (left Whisker)
#     2. 25th Quantile(Q1)
#     3. 50th quantile(Q2)
#     4. 75th Quantile(q3)
#     5. Max(Right Whisker)
#     6. IQR = q3-q1
# ii. Describe the various components of a box plot in detail? When will the lower whisker surpass the upper whisker in length? How can box plots be used to identify outliers?
#     Boxplot represents data in terms of quartiles. Complete distribution of data is divided into quartiles (4) based on the value of data points. The top 75% is categorised as 3 quartile, The value at 50th quantile is the median of the data. The left hand whisker determines the minimum value, then 25th Quantile(Q1), 50th quantile(Q2), 75 Quantile(Q3) and then right hand whisker represents max value.
#     1. Min Value (left Whisker)
#     2. 25th Quantile(Q1)
#     3. 50th quantile(Q2)
#     4. 75th Quantile(q3)
#     5. Max(Right Whisker)
#     6. IQR = q3-q1
# When the data is left skewed then it will have most of the data lying in the lower portion of boxplot. If most of the data lie below q1 then lower whisker will be longer.
#
#
# 10. Make brief notes on any two of the following:
#
# 1. Data collected at regular intervals
# To find the exact distribution of data, we create bins of regular size and based on probability distribution data is put.
# 2. The gap between the quartiles
#
# 3. Use a cross-tab
# Chi Square Test uses cross tabs to find if the groups/classes present in one column is creating any significant impact on any other column or not. For example There are 3 categories in SubjectColumn ["Phy", "Chem", "MAths"] and there is a Percentage_Scored Column. questions like Does Students who opted Phy have secured better marks than Students who opted Chem and MAths.
#
# 11. Make a comparison between:
#
# 1. Data with nominal and ordinal values
# Ordinal: Where order matters. EXample: Movie Ratings["Good","BAd","Worst"]
# Nominal: Notational DAta where order doesnt matter. EXample Gender["MAle","Female"]
#
# 2. Histogram and box plot
# Histogram: usually designed for continous data where the frequency is calculated over a range of values in terms of probability distribution.
# Boxplot represents data in terms of quartiles. Complete distribution of data is divided into quartiles (4) based on the value of data points. The top 75% is categorised as 3 quartile, The value at 50th quantile is the median of the data. The left hand whisker determines the minimum value, then 25th Quantile(Q1), 50th quantile(Q2), 75 Quantile(Q3) and then right hand whisker represents max value.
#
# 3. The average and median
# There is a mathematical calculation involved in Mean : Sum of all points/ total number of points. Increasing value of one of the datapoints can drastically bring effect in overall calculation and bringing right /left skewness. Howsoever median is calculated by arranging the datapoints in the order of mangintude and middle value is taken in case odd number of data points and average of two middle values are taken in case of even number of data points and thus median doesnt get affected by outliers.
